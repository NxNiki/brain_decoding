# %%
import warnings
import os
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from brain_decoding.config.file_path import RESULT_PATH, DATA_PATH
from brain_decoding.utils.analysis import concept_frequency, add_label_count, plot_concept_graph

from brain_decoding.param.param_data import TWILIGHT_LABELS, MOVIE24_LABELS
from brain_decoding.param.param_data import TWILIGHT_LABELS_MERGE as labels
from brain_decoding.config.file_path import TWILIGHT_MERGE_LABEL_PATH, TWILIGHT_LABEL_PATH, MOVIE24_LABEL_PATH, RESULT_PATH

# Suppress all UserWarning messages
# warnings.filterwarnings('ignore', category=UserWarning)

# %% [markdown]
# ## Count the number of 250 ms intervals for each concept in Twilight:

# %%
print(TWILIGHT_LABEL_PATH)
# Out:
# /Users/XinNiuAdmin/Documents/brain_decoding/data/twilight_concepts.npy

# %%
concept_count, _ = concept_frequency(TWILIGHT_LABEL_PATH, TWILIGHT_LABELS)
print(concept_count)
# Out:
# {'Alice.Cullen': 175, 'Angela.Weber': 842, 'Bella.Swan': 6385, 'Billy.Black': 209, 'Carlisle.Cullen': 184, 'Charlie.Swan': 1031, 'Edward.Cullen': 2582, 'Emmett.Cullen': 139, 'Eric.Yorkie': 474, 'Jacob.Black': 677, 'Jasper.Hale': 176, 'Jessica.Stanley': 1047, 'Mike.Newton': 446, 'No.Characters': 1245, 'Rosalie.Hale': 136, 'Side.Character': 1408, 'Renee.Swan': 68, 'Tyler.Crowley': 275}

# %%
result_path = os.path.join(RESULT_PATH, 'concept_co-occurence_twilight.png')
plot_concept_graph(TWILIGHT_LABEL_PATH, TWILIGHT_LABELS, result_path)

# %% [markdown]
# # Merged concepts for twilight
# `No.Characters` is recalculated to avoid overlaps in the edges.
#
# `Bella.Swan` and `Edward.Cullen` are set to 0 if cooccurrence with any of the other characters (including the other of them).
#
# `Others` is 1 if any of the other characters appear without `Bella.Swan` and `Edward.Cullen`.

# %%
concept_count, _ = concept_frequency(TWILIGHT_MERGE_LABEL_PATH, labels)
print(concept_count)
# Out:
# {'Bella.Swan': 2492, 'Edward.Cullen': 2234, 'No.Characters': 1245, 'Others': 4829}

# %% [markdown]
# ## Plot co-occurrence graph for movie 24:

# %%
print(MOVIE24_LABEL_PATH)
# Out:
# /Users/XinNiuAdmin/Documents/brain_decoding/data/8concepts_merged.npy

# %%
result_path = os.path.join(RESULT_PATH, 'concept_co-occurence_24.png')
plot_concept_graph(MOVIE24_LABEL_PATH, MOVIE24_LABELS, result_path)
